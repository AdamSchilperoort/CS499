# %% [markdown]
# # Lab00: Introduction to NetworkX and Gephi

# %% [markdown]
# ## Part 2, cntd.: Introduction to Jupyter Notebook

# %% [markdown]
# Welcome to Jupyter Notebook! In this section, you will complete some basic tasks that will help illuminate some of Jupyter's basic functionality and purpose in your learning.
#
# ### Data stories
# "Data science" is something of a buzz word right now. At its core, it's about extracting useful insights from data. A critical part of data science is being able to tell a story using data. This involves having a narrative structure that incorporates data into its arc. The important focus for this class will be the way that data stories are used to explain _what_ we are doing to data at a specific point in our analytical process (_when_) and _how_ we are doing it (methodology) and _why_ we are doing those things to the data. Not only does this make our analysis and research reproducible, it is also understandable and broadly meaningful. In this lab, you will be practicing your data storytelling skills.

# %% [markdown]
# ### Generating Markdown content for you data story
#
# Markdown is a lightweight markup language that allows you to format text. You will be using the Markdown in Jupyter to generate tables, embed images, and write formatted text.
#
# To create new Markdown content, you can select the plus sign icon from the Jupyter Notebook menu (circled in green) in order to create a new cell. Make sure the format selected is "Markdown" (circled in blue). Once you have finished adding new Markdown content into the cell, you can compile it by clicking the play icon from the Jupyter Notebook menu (circled in red).
#
# Your unrendered content will look like the image below.
#
# ![alt text](lab00_intro/unrendered_markdown.png "Unrendered Markdown content")
#
#
# I highly recommend you check out this [this Markdown cheatsheet](https://github.com/adam-p/markdown-here/wiki/Markdown-Cheatsheet "Markdown Cheatsheet")

# %% [markdown]
# ## Part 3: Introduction to NetworkX

# %% [markdown]
# ### Creating networks with NetworkX
# Now that you have been exposed to some of the basics of Jupyter Notebook's Markdown capabilities, let's dive into Python's NetworkX.
#
# [NetworkX](https://networkx.github.io/documentation/stable/ "NetworkX 2.2 Documentation") is a Python package that supports the creation and study of complex networks. We will be using the stable version 2.2. From your cs499 venv in the terminal (NOT a Jupyter Notebook cell), you can install NetworkX by running the following:
#
# ```
# pip3 install networkx==2.2
#
# ```

# %% [markdown]
# First, let's try to import NetworkX into our Jupyter Notebook.
# In the Python cell below, write:
#
# ```
# import networkx as nx
# ```
#
# Run the cell (by clicking the play icon in the Jupyter Notebook menu). It should complete with a number in the brackets next to the cell.

# %%
import networkx as nx

# %% [markdown]
# Now that we have imported NetworkX, we can use it anywhere in our notebook. Let's start by creating a simple network using NetworkX's Graph class.

# %%
# Creating a new complex network with Graph
G = nx.Graph()

# Next, we will add a node with an ID of 1
G.add_node(1)

# We can also add multiple nodes at a time using a list
G.add_nodes_from([2,3])

# %% [markdown]
# Let's draw our growing network, _G_, as we start adding components to it. We need to use matplotlib.pyplot for this. You can install matplotlib using the following command in your terminal:
#
#     pip3 install matplotlib

# %%
import matplotlib.pyplot as plt

# Create a subplot in which to draw your network
plt.subplot(121)

# Draw G
nx.draw(G, with_labels=True, font_weight='bold')

# Show the drawing
plt.show()

# %% [markdown]
# Let's add some edges. There are a number of ways to add edges. We will explore adding unweighted and weighted edges as well as adding colors to edges.

# %%
# Add edges
G.add_edge(1,2)
G.add_edge(1,3)
G.add_edge(2,3)

# Create a subplot in which to draw your network
plt.subplot(122)

# Draw G
nx.draw(G, with_labels=True, font_weight='bold')

# Show the drawing
plt.show()
# Out:
# /Users/adamschilperoort/Desktop/Spring2020/CS499/cs499/lib/python3.7/site-packages/networkx/drawing/nx_pylab.py:563: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if not cb.iterable(width):
# /Users/adamschilperoort/Desktop/Spring2020/CS499/cs499/lib/python3.7/site-packages/networkx/drawing/nx_pylab.py:611: MatplotlibDeprecationWarning:
# The is_numlike function was deprecated in Matplotlib 3.0 and will be removed in 3.2. Use isinstance(..., numbers.Number) instead.
#   if cb.is_numlike(alpha):

# %% [markdown]
# Now let's look at how to access nodes and edges from a Graph object.

# %%
nodes = G.nodes()
edges = G.edges()

print("These are the nodes:")
print(nodes)

print("These are the edges:")
print(edges)
# Out:
# These are the nodes:
# [1, 2, 3]
# These are the edges:
# [(1, 2), (1, 3), (2, 3)]

# %% [markdown]
# Note that this is an undirected graph. We can create an directed graph in NetworkX as well.

# %%
# Create a directed graph
DG = nx.DiGraph()

# Add some weighted edges to the graph.
# The edge format is a triple with the endpoints and the weight.
# Note that we can use strings as nodes
DG.add_weighted_edges_from([("A", "B", 0.5), ("C", "A", 0.75)])

# Create a subplot in which to draw your network
plt.subplot(122)

# Draw G
nx.draw(DG, with_labels=True, font_weight='bold')

# Show the drawing
plt.show()
# Out:
# /Users/adamschilperoort/Desktop/Spring2020/CS499/cs499/lib/python3.7/site-packages/networkx/drawing/nx_pylab.py:660: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if cb.iterable(node_size):  # many node sizes

# %% [markdown]
# **!!! TODO: Q0 !!!**
#
# Now it is your turn to practice creating a network with NetworkX. In Python cells below, generate a network that looks like this:
#
# ![graph.gif](graph.gif "Network that you must create in a Python cell below.")
#
# Write code to draw your network.

# %%
import networkx as nx
import matplotlib.pyplot as plt

# Create a complex network with Graph
G = nx.Graph()

# Add nodes A to G
G.add_node("A")
G.add_node("B")
G.add_node("C")
G.add_node("D")
G.add_node("E")
G.add_node("F")
G.add_node("G")

# Add edges between nodes with corresponding weights
G.add_edge("A","B", weight = 2)
G.add_edge("A","D", weight = 3)
G.add_edge("B","C", weight = 3)
G.add_edge("B","E", weight = 2)
G.add_edge("D","F", weight = 4)
G.add_edge("D","G", weight = 1)
G.add_edge("B","F", weight = 1)
G.add_edge("E","F", weight = 3)
G.add_edge("G","F", weight = 7)

# Create labels for weights (this should work but doesn't for some reason)
labels=nx.get_edge_attributes(G,'weight')

# Create a subplot to draw network
plt.subplot(121)

# Draw G
nx.draw(G, with_labels=True, node_size=800, node_color='r', edge_labels=labels, font_family='sans-serif')

# Show the drawing
plt.show()
# Out:
# /Users/adamschilperoort/Desktop/Spring2020/CS499/cs499/lib/python3.7/site-packages/networkx/drawing/nx_pylab.py:563: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if not cb.iterable(width):
# /Users/adamschilperoort/Desktop/Spring2020/CS499/cs499/lib/python3.7/site-packages/networkx/drawing/nx_pylab.py:611: MatplotlibDeprecationWarning:
# The is_numlike function was deprecated in Matplotlib 3.0 and will be removed in 3.2. Use isinstance(..., numbers.Number) instead.
#   if cb.is_numlike(alpha):

# %% [markdown]
# You will be responsible for exploring the NetworkX documentation to complete subsequent labs.
#
# I suggest combing through this [tutorial](https://networkx.github.io/documentation/stable/tutorial.html "NetworkX tutorial").
#
# I also suggest becoming familiar with the [NetworkX documentation](https://networkx.github.io/documentation/stable/reference/index.html)

# %% [markdown]
# ### Characterizing networks
#
# An important way we will be using NetworkX is to characterize networks. Start generating an instance of the well-known Karate Club graph.

# %%
# There are some pre-defined, real-world networks
# that are accessible via the NetworkX API
G = nx.karate_club_graph()

# Use a spring layout to spread nodes apart for a drawing
pos = nx.spring_layout(G)

plt.figure(figsize=(12,8))
nx.draw_networkx(G, pos=pos, node_color="gray", node_size=640)
limits = plt.axis('off')
plt.show()

# %% [markdown]
# Let's start with basic metrics, like the number of nodes, the number of edges and the degree distribution of each edge. Read through the [functional documentation](https://networkx.github.io/documentation/stable/reference/functions.html) in order to complete the TODO items below.
#
# **!!! TODO !!!**
# 1. Calculate the number of nodes in the Karate Club graph, _G_
# 2. Calculate the number of edges in the Karate Club graph, _G_
# 3. Calculate the density of the Karate Club graph, _G_

# %%
# Add karate club graph onto G object
G = nx.karate_club_graph()

# Calculate the number of nodes in G
n = nx.number_of_nodes(G)
print("Number of nodes: %s" % n)

# Calculate the number of edges in G
e = nx.number_of_edges(G)
print("Number of edges: %s" % e)

# Calculate the density of G
D = nx.density(G)
print("Density: %s" % D)
# Out:
# Number of nodes: 34
# Number of edges: 78
# Density: 0.13903743315508021
